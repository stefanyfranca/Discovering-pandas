# %%
import pandas as pd

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"

# Extraindo
df_tips = pd.read_csv(url)

# Vamos "sujar" um pouco os dados para o desafio fazer sentido
df_tips.iloc[0, 0] = -10.50  # Um valor negativo impossível
df_tips.iloc[1, 2] = "No "   # Um texto com espaço extra
df_tips.iloc[2, 1] = None    # Um valor nulo
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       3 # Base de dados de vendas reais (e-commerce)
#       4 url = "https://raw.githubusercontent.com/lucasgalvao/dataset-vendas/master/vendas.csv"
#       5
#       6 # Extraindo
# ----> 7 df_vendas = pd.read_csv(url)
#       8 print(df_vendas.head())
#
# ...
