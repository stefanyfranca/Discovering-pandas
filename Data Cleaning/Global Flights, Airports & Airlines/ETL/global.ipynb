# %%
import pandas as pd

df_airlines = pd.read_csv('/home/stefanyfranca/Área de trabalho/Discovering-pandas/Data Cleaning/Global Flights, Airports & Airlines/Data/airlines.csv')
df_airports = pd.read_csv('/home/stefanyfranca/Área de trabalho/Discovering-pandas/Data Cleaning/Global Flights, Airports & Airlines/Data/airports.csv')
df_routes = pd.read_csv('/home/stefanyfranca/Área de trabalho/Discovering-pandas/Data Cleaning/Global Flights, Airports & Airlines/Data/routes.csv')

# %%
american_airports = df_airports[df_airports['iso_country'] == 'US']
print(american_airports)
# Out:
#            id    ident           type                     name  latitude_deg  \
# 0        6523      00A       heliport        Total RF Heliport     40.070985
# 1      323361     00AA  small_airport     Aero B Ranch Airport     38.704022
# 2        6524     00AK  small_airport             Lowell Field     59.947733
# 3        6525     00AL  small_airport             Epps Airpark     34.864799
# 4      506791     00AN  small_airport     Katmai Lodge Airport     59.093287
# ...       ...      ...            ...                      ...           ...
# 84300   26366      Z92  small_airport   Harsens Island Airport     42.589699
# 84301   26367      Z93  small_airport  Copper Center 2 Airport     61.943713
# 84302   26368      Z95  small_airport          Cibecue Airport     34.001681
# 84866   26369      ZNC  small_airport             Nyac Airport     60.980701
# 85114  346788  ZZ-0003  small_airport    Fainting Goat Airport     32.110587
#
#        longitude_deg  elevation_ft continent iso_country iso_region  \
# 0         -74.933689          11.0       NaN          US      US-PA
# 1        -101.473911        3435.0       NaN          US      US-KS
# 2        -151.692524         450.0       NaN          US      US-AK
# 3         -86.770302         820.0       NaN          US      US-AL
# 4        -156.456699          80.0       NaN          US      US-AK
# ...              ...           ...       ...         ...        ...
# 84300     -82.576401         578.0       NaN          US      US-MI
# 84301    -145.299398        1150.0       NaN          US      US-AK
# 84302    -110.455115        5037.0       NaN          US      US-AZ
# 84866    -159.994003         460.0       NaN          US      US-AK
# 85114     -97.356312         690.0       NaN          US      US-TX
#
#          municipality scheduled_service icao_code iata_code gps_code  \
# 0            Bensalem                no       NaN       NaN     K00A
# 1               Leoti                no       NaN       NaN     00AA
# 2        Anchor Point                no       NaN       NaN     00AK
# 3             Harvest                no       NaN       NaN     00AL
# 4         King Salmon                no       NaN       NaN     00AN
# ...               ...               ...       ...       ...      ...
# 84300  Harsens Island                no       NaN       NaN      Z92
# 84301   Copper Center                no       NaN       CZC      NaN
# 84302         Cibecue                no       NaN       NaN      NaN
# 84866            Nyac                no       NaN       ZNC      ZNC
# 85114            Blum                no       NaN       NaN     87TX
#
#       local_code                                          home_link  \
# 0            00A  https://www.penndot.pa.gov/TravelInPA/airports...
# 1           00AA                                                NaN
# 2           00AK                                                NaN
# 3           00AL                                                NaN
# 4           00AN                                                NaN
# ...          ...                                                ...
# 84300        Z92                                                NaN
# 84301        Z93                                                NaN
# 84302        Z95                                                NaN
# 84866        ZNC                                                NaN
# 85114       87TX                                                NaN
#
#                                           wikipedia_link keywords
# 0                                                    NaN      NaN
# 1                                                    NaN      NaN
# 2                                                    NaN      NaN
# 3                                                    NaN      NaN
# 4                                                    NaN      NaN
# ...                                                  ...      ...
# 84300                                                NaN      NaN
# 84301  https://en.wikipedia.org/wiki/Copper_Center_Ai...      NaN
# 84302      https://en.wikipedia.org/wiki/Cibecue_Airport      NaN
# 84866         https://en.wikipedia.org/wiki/Nyac_Airport      NaN
# 85114                                                NaN      NaN
#
# [32452 rows x 19 columns]

# %%
american_airports_states = american_airports.groupby('iso_region').size().reset_index(name='count')
print(american_airports_states)
# Out:
#    iso_region  count
# 0       US-AK   1073
# 1       US-AL    505
# 2       US-AR    780
# 3       US-AZ    998
# 4       US-CA   2427
# 5       US-CO    670
# 6       US-CT    171
# 7       US-DC     24
# 8       US-DE     62
# 9       US-FL   1363
# 10      US-GA    676
# 11      US-HI    129
# 12      US-IA    423
# 13      US-ID    474
# 14      US-IL   1119
# 15      US-IN    795
# 16      US-KS    591
# 17      US-KY    338
# 18      US-LA    871
# 19      US-MA    276
# 20      US-MD    297
# 21      US-ME    280
# 22      US-MI    691
# 23      US-MN    696
# 24      US-MO    756
# 25      US-MS    451
# 26      US-MT    464
# 27      US-NC    633
# 28      US-ND    356
# 29      US-NE    372
# 30      US-NH    213
# 31      US-NJ    475
# 32      US-NM    450
# 33      US-NV    427
# 34      US-NY    803
# 35      US-OH    935
# 36      US-OK    710
# 37      US-OR    712
# 38      US-PA   1078
# 39      US-RI     45
# 40      US-SC    275
# 41      US-SD    264
# 42      US-TN    457
# 43      US-TX   3859
# 44     US-U-A      1
# 45      US-UT    432
# 46      US-VA    590
# 47      US-VT    122
# 48      US-WA    754
# 49      US-WI    692
# 50      US-WV    156
# 51      US-WY    241
