# %%
import pandas as pd

df_airlines = pd.read_csv('/home/stefanyfranca/Área de trabalho/Discovering-pandas/Data Cleaning/Global Flights, Airports & Airlins/Data/airlines.csv')
df_airports = pd.read_csv('/home/stefanyfranca/Área de trabalho/Discovering-pandas/Data Cleaning/Global Flights, Airports & Airlins/Data/airports.csv')
df_routes = pd.read_csv('/home/stefanyfranca/Área de trabalho/Discovering-pandas/Data Cleaning/Global Flights, Airports & Airlins/Data/routes.csv')

# %%
df_airlines.isnull().sum()
# Out:
# airline_id        0
# airline_name      0
# alias           338
# iata_code         2
# icao_code       275
# callsign        395
# country           9
# active            0
# dtype: int64

# %%
# Out:
# <StringArray>
# [ '3H',  '4E',  '4W',  '5U',  '6L',  '7S',  '9D',  '9M', 'ABJ',  'EB',  'HS',
#  'IOS', 'NHG',  'O4',  'P1',  'P2',  'P6',  'PB', 'TCX', 'TOM',  'WT',  'X4',
#   'XU',  'YJ',  'YN',  'ZD']
# Length: 26, dtype: str
